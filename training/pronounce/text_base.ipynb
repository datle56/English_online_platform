# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer

# %%
from huggingface_hub import login

hf_token = "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"
login(hf_token, add_to_git_credential=True)

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Downloading:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading and preparing dataset timit_asr/clean (download: 828.75 MiB, generated: 7.90 MiB, post-processed: Unknown size, total: 836.65 MiB) to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad...
# Downloading:   0%|          | 0.00/869M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset timit_asr downloaded and prepared to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 4620
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 1680
#     })
# })

# %%
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id"])

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)

    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Steve collects rare and novel coins.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>She had your dark suit in greasy wash water all year.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Then we were off again.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Those lovely whorls, he chortled.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>She had your dark suit in greasy wash water all year.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Their privations are almost beyond endurance.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>They remained lifelong friends and companions.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>To his puzzlement, there suddenly was no haze.</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Bob found more clams at the ocean's edge.</td>
#     </tr>
#   </tbody>
# </table>

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
timit = timit.map(remove_special_characters)
# Out:
# WARNING:datasets.fingerprint:Parameter 'function'=<function remove_special_characters at 0x7951671d3250> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>technical writers can abbreviate in bibliographies</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>the irate actor stomped away idiotically</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>porcupines resemble sea urchins</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>in fact nobody saw us cop or citizen</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>in earlier years the preservation of food was essentially related to survival</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>he had always been a messy and negligent man</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>a bayonet hung in a belt scabbard</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>clasp the screw in your left hand</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>a young mouse scampered across the field and disappeared</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>my instructions desperately need updating</td>
#     </tr>
#   </tbody>
# </table>

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = timit.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=timit.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]) | set(vocabs["test"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'v': 0,
#  'n': 1,
#  'j': 2,
#  't': 3,
#  'i': 4,
#  'g': 5,
#  'd': 6,
#  'k': 7,
#  'q': 8,
#  's': 9,
#  'w': 10,
#  'b': 11,
#  'm': 12,
#  'l': 13,
#  ' ': 14,
#  'h': 15,
#  'o': 16,
#  'e': 17,
#  'f': 18,
#  'r': 19,
#  'x': 20,
#  'u': 21,
#  'y': 22,
#  "'": 23,
#  'c': 24,
#  'z': 25,
#  'p': 26,
#  'a': 27}

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 30

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from datasets import DatasetDict, Dataset

# Chuyển cả train và test sang pandas DataFrame
train_data_df = timit["train"].to_pandas()
test_data_df = timit["test"].to_pandas()

# Gộp cả train và test lại
all_data_df = pd.concat([train_data_df, test_data_df], ignore_index=True)

# Chia thành 70% train, 15% valid, 15% test
train_split, temp_split = train_test_split(all_data_df, test_size=0.30, random_state=42)  # 70% train, còn lại để chia tiếp
valid_split, test_split = train_test_split(temp_split, test_size=0.50, random_state=42)   # Chia 15% valid, 15% test

# Chuyển các DataFrame trở lại dạng Dataset
train_dataset = Dataset.from_pandas(train_split)
valid_dataset = Dataset.from_pandas(valid_split)
test_dataset = Dataset.from_pandas(test_split)

# Tạo DatasetDict mới với các tập đã định nghĩa
timit_split = DatasetDict({
    "train": train_dataset,
    "valid": valid_dataset,
    "test": test_dataset
})

# Kiểm tra kích thước
print(f"Số mẫu trong tập train: {len(timit_split['train'])}")
print(f"Số mẫu trong tập valid: {len(timit_split['valid'])}")
print(f"Số mẫu trong tập test: {len(timit_split['test'])}")
# Out:
# Số mẫu trong tập train: 4410
# Số mẫu trong tập valid: 945
# Số mẫu trong tập test: 945

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
timit = timit_split

# %%
timit["train"][0]["file"]
# Out:
# '/root/.cache/huggingface/datasets/downloads/extracted/404950a46da14eac65eb4e2a8317b1372fb3971d980d91d5d5b221275b1fd7e0/data/TEST/DR7/MPAB0/SA1.WAV'

# %%
from datasets import Audio

# Gắn kiểu dữ liệu audio cho cả train, valid và test
timit = timit.cast_column("audio", Audio(sampling_rate=16000))

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(timit["train"]))

print(timit["train"][rand_int]["text"])
ipd.Audio(data=np.asarray(timit["train"][rand_int]["audio"]["array"]), autoplay=True, rate=16000)
# Out:
# passing dogs were greeted with a cordial bark
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_int = random.randint(0, len(timit["train"]))

print("Target text:", timit["train"][rand_int]["text"])
print("Input array shape:", np.asarray(timit["train"][rand_int]["audio"]["array"]).shape)
print("Sampling rate:", timit["train"][rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: tugboats are capable of hauling huge loads
# Input array shape: (42496,)
# Sampling rate: 16000

# %%
from datasets import Audio

# Gắn kiểu dữ liệu audio cho cả train, valid và test
timit = timit.cast_column("audio", Audio(sampling_rate=16000))

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
np.object = object

# %%
timit = timit.map(prepare_dataset, remove_columns=timit.column_names["train"])
# Out:
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
max_input_length_in_sec = 4.0
timit["train"] = timit["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %%
wer_metric = load_metric("wer")
# Out:
# Downloading:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC, Wav2Vec2Config

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base-960h",
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# Downloading:   0%|          | 0.00/1.56k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py:1439: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(resolved_archive_file, map_location="cpu")
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base-960h and are newly initialized: ['wav2vec2.masked_spec_embed']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.freeze_feature_encoder()

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir='./testlaibasettsgopdata/',
  group_by_length=True,
  per_device_train_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=30,
  fp16=True,
  gradient_checkpointing=True,
  save_steps=500,
  eval_steps=500,
  logging_steps=500,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=1000,
  save_total_limit=2,
  load_best_model_at_end=True,
  push_to_hub=True,
)

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=timit["train"],
    eval_dataset=timit["valid"],
    tokenizer=processor.feature_extractor,
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/tinybee/testlaibasettsgopdata into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/tinybee/testlaibasettsgopdata into local empty directory.
# Using amp half precision backend
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:474: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler()

# %%
np.bool = bool

# %%
import os
import numpy as np
import pandas as pd
import torchaudio

os.environ["WANDB_DISABLED"] = "true"

# %%
trainer.train()
# Out:
# The following columns in the training set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 3797
#   Num Epochs = 30
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 14250
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.18.7
# W&B syncing is set to <code>`offline`<code> in this directory.  <br/>Run <code>`wandb online`<code> or set <code>WANDB_MODE=online<code> to enable cloud syncing.
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='7501' max='14250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7501/14250 1:01:33 < 55:23, 2.03 it/s, Epoch 15.79/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>6.271600</td>
#       <td>3.054977</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.826200</td>
#       <td>0.266860</td>
#       <td>0.302331</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.546900</td>
#       <td>0.180923</td>
#       <td>0.228098</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.354100</td>
#       <td>0.154129</td>
#       <td>0.218528</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.336700</td>
#       <td>0.143158</td>
#       <td>0.205399</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.279200</td>
#       <td>0.121790</td>
#       <td>0.202331</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.241100</td>
#       <td>0.113579</td>
#       <td>0.202945</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.204100</td>
#       <td>0.142284</td>
#       <td>0.202454</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.226200</td>
#       <td>0.129377</td>
#       <td>0.196810</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.192100</td>
#       <td>0.123719</td>
#       <td>0.195215</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.187700</td>
#       <td>0.104335</td>
#       <td>0.188957</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.176000</td>
#       <td>0.127219</td>
#       <td>0.193497</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.123600</td>
#       <td>0.135166</td>
#       <td>0.190184</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.147300</td>
#       <td>0.125651</td>
#       <td>0.187362</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.174800</td>
#       <td>0.118984</td>
#       <td>0.185399</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-1000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-1000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-1000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-1000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-1500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-1500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-1500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-1500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-2000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-2000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-2000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-2000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-1000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-2500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-2500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-2500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-2500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-1500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-3000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-3000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-3000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-3000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-2000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-3500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-3500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-3500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-3500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-2500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-4000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-4000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-4000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-4000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-3000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-4500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-4500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-4500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-4500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-4000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-5000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-5000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-5000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-5000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-4500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-5500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-5500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-5500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-5500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-3500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-6000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-6000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-6000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-6000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-5000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-6500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-6500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-6500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-6500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-6000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-7000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-7000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-7000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-7000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-6500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-7500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-7500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-7500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-7500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-7000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='14250' max='14250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14250/14250 2:00:31, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Wer</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>6.271600</td>
#       <td>3.054977</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.826200</td>
#       <td>0.266860</td>
#       <td>0.302331</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.546900</td>
#       <td>0.180923</td>
#       <td>0.228098</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.354100</td>
#       <td>0.154129</td>
#       <td>0.218528</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.336700</td>
#       <td>0.143158</td>
#       <td>0.205399</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.279200</td>
#       <td>0.121790</td>
#       <td>0.202331</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.241100</td>
#       <td>0.113579</td>
#       <td>0.202945</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.204100</td>
#       <td>0.142284</td>
#       <td>0.202454</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.226200</td>
#       <td>0.129377</td>
#       <td>0.196810</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.192100</td>
#       <td>0.123719</td>
#       <td>0.195215</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.187700</td>
#       <td>0.104335</td>
#       <td>0.188957</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.176000</td>
#       <td>0.127219</td>
#       <td>0.193497</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.123600</td>
#       <td>0.135166</td>
#       <td>0.190184</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.147300</td>
#       <td>0.125651</td>
#       <td>0.187362</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.174800</td>
#       <td>0.118984</td>
#       <td>0.185399</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.114700</td>
#       <td>0.121321</td>
#       <td>0.191411</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.150800</td>
#       <td>0.126158</td>
#       <td>0.181350</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.106100</td>
#       <td>0.114820</td>
#       <td>0.180245</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.118200</td>
#       <td>0.103361</td>
#       <td>0.175828</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.114400</td>
#       <td>0.112341</td>
#       <td>0.176933</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.088500</td>
#       <td>0.104327</td>
#       <td>0.173497</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.079700</td>
#       <td>0.100353</td>
#       <td>0.171166</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.072900</td>
#       <td>0.104535</td>
#       <td>0.170307</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.071800</td>
#       <td>0.106400</td>
#       <td>0.171166</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.066800</td>
#       <td>0.104951</td>
#       <td>0.168712</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.059900</td>
#       <td>0.096529</td>
#       <td>0.167730</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.070200</td>
#       <td>0.093024</td>
#       <td>0.168221</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.094200</td>
#       <td>0.095853</td>
#       <td>0.167362</td>
#     </tr>
#   </tbody>
# </table><p>
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-8000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-8000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-8000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-8000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-7500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-8500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-8500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-8500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-8500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-8000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-9000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-9000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-9000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-9000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-8500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-9500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-9500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-9500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-9500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-5500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-10000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-10000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-10000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-10000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-9000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-10500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-10500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-10500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-10500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-10000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-11000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-11000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-11000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-11000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-9500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-11500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-11500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-11500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-11500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-10500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-12000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-12000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-12000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-12000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-11500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-12500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-12500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-12500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-12500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-12000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-13000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-13000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-13000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-13000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-11000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-13500
# Configuration saved in ./testlaibasettsgopdata/checkpoint-13500/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-13500/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-13500/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-12500] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
# Saving model checkpoint to ./testlaibasettsgopdata/checkpoint-14000
# Configuration saved in ./testlaibasettsgopdata/checkpoint-14000/config.json
# Model weights saved in ./testlaibasettsgopdata/checkpoint-14000/pytorch_model.bin
# Feature extractor saved in ./testlaibasettsgopdata/checkpoint-14000/preprocessor_config.json
# Feature extractor saved in ./testlaibasettsgopdata/preprocessor_config.json
# Deleting older checkpoint [testlaibasettsgopdata/checkpoint-13000] due to args.save_total_limit
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1949: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   ctx_manager = autocast(dtype=self.amp_dtype)
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./testlaibasettsgopdata/checkpoint-13500 (score: 0.09302354604005814).
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1535: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(best_model_path, map_location="cpu")
# TrainOutput(global_step=14250, training_loss=0.4395039008960389, metrics={'train_runtime': 7241.158, 'train_samples_per_second': 15.731, 'train_steps_per_second': 1.968, 'total_flos': 2.9346334970212946e+18, 'train_loss': 0.4395039008960389, 'epoch': 30.0})

# %%
trainer.evaluate(timit["valid"])
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 945
#   Batch size = 8
#     <div>
#
#       <progress value='119' max='119' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [119/119 00:33]
#     </div>
# {'eval_loss': 0.09302354604005814,
#  'eval_wer': 0.1682208588957055,
#  'eval_runtime': 34.3078,
#  'eval_samples_per_second': 27.545,
#  'eval_steps_per_second': 3.469,
#  'epoch': 30.0}

# %%
trainer.save_model()

# %%
def map_to_result(batch):
  with torch.no_grad():
    input_values = torch.tensor(batch["input_values"], device="cuda").unsqueeze(0)
    logits = model(input_values)[0]

  pred_ids = torch.argmax(logits, dim=-1)
  batch["pred_str"] = processor.batch_decode(pred_ids)[0]
  batch["text"] = processor.decode(batch["labels"], group_tokens=False)

  return batch

# %%
results = timit["test"].map(map_to_result, remove_columns=timit["test"].column_names)

# %%
print("Test WER: {:.3f}".format(wer_metric.compute(predictions=results["pred_str"], references=results["text"])))
# Out:
# Test WER: 0.051

# %%
results[0:9]
